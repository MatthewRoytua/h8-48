# %%
# !pip install Pandas
# Out:
# Requirement already satisfied: Pandas in c:\users\roytu\anaconda3\lib\site-packages (1.1.3)
# Requirement already satisfied: pytz>=2017.2 in c:\users\roytu\anaconda3\lib\site-packages (from Pandas) (2020.1)
# Requirement already satisfied: numpy>=1.15.4 in c:\users\roytu\anaconda3\lib\site-packages (from Pandas) (1.19.2)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\roytu\anaconda3\lib\site-packages (from Pandas) (2.8.1)
# Requirement already satisfied: six>=1.5 in c:\users\roytu\anaconda3\lib\site-packages (from python-dateutil>=2.7.3->Pandas) (1.15.0)

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('https://raw.githubusercontent.com/ardhiraka/PFDS_sources/master/nbaallelo.csv')

# %%
len(df)
# Out:
# 126314

# %%
df.shape
# Out:
# (126314, 23)

# %%
df.tail(5)
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id  date_game  \
# 126309      63155  201506110CLE   NBA        0     2015  6/11/2015
# 126310      63156  201506140GSW   NBA        0     2015  6/14/2015
# 126311      63156  201506140GSW   NBA        1     2015  6/14/2015
# 126312      63157  201506170CLE   NBA        0     2015  6/16/2015
# 126313      63157  201506170CLE   NBA        1     2015  6/16/2015
#
#         seasongame  is_playoffs team_id    fran_id  ...  win_equiv  opp_id  \
# 126309         100            1     CLE  Cavaliers  ...  60.309792     GSW
# 126310         102            1     GSW   Warriors  ...  68.013329     CLE
# 126311         101            1     CLE  Cavaliers  ...  60.010067     GSW
# 126312         102            1     CLE  Cavaliers  ...  59.290245     GSW
# 126313         103            1     GSW   Warriors  ...  68.519516     CLE
#
#          opp_fran  opp_pts  opp_elo_i  opp_elo_n  game_location  game_result  \
# 126309   Warriors      103  1790.9591  1809.9791              H            L
# 126310  Cavaliers       91  1704.3949  1700.7391              H            W
# 126311   Warriors      104  1809.9791  1813.6349              A            L
# 126312   Warriors      105  1813.6349  1822.2881              H            L
# 126313  Cavaliers       97  1700.7391  1692.0859              A            W
#
#         forecast notes
# 126309  0.546572   NaN
# 126310  0.765565   NaN
# 126311  0.234435   NaN
# 126312  0.481450   NaN
# 126313  0.518550   NaN
#
# [5 rows x 23 columns]

# %%
pd.set_option("display.precision",2)

# %%
df.head()
# Out:
#    gameorder       game_id lg_id  _iscopy  year_id  date_game  seasongame  \
# 0          1  194611010TRH   NBA        0     1947  11/1/1946           1
# 1          1  194611010TRH   NBA        1     1947  11/1/1946           1
# 2          2  194611020CHS   NBA        0     1947  11/2/1946           1
# 3          2  194611020CHS   NBA        1     1947  11/2/1946           2
# 4          3  194611020DTF   NBA        0     1947  11/2/1946           1
#
#    is_playoffs team_id  fran_id  ...  win_equiv  opp_id  opp_fran  opp_pts  \
# 0            0     TRH  Huskies  ...      40.29     NYK    Knicks       68
# 1            0     NYK   Knicks  ...      41.71     TRH   Huskies       66
# 2            0     CHS    Stags  ...      42.01     NYK    Knicks       47
# 3            0     NYK   Knicks  ...      40.69     CHS     Stags       63
# 4            0     DTF  Falcons  ...      38.86     WSC  Capitols       50
#
#   opp_elo_i opp_elo_n  game_location  game_result  forecast notes
# 0   1300.00   1306.72              H            L      0.64   NaN
# 1   1300.00   1293.28              A            W      0.36   NaN
# 2   1306.72   1297.07              H            W      0.63   NaN
# 3   1300.00   1309.65              A            L      0.37   NaN
# 4   1300.00   1320.38              H            L      0.64   NaN
#
# [5 rows x 23 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 126314 entries, 0 to 126313
# Data columns (total 23 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   gameorder      126314 non-null  int64
#  1   game_id        126314 non-null  object
#  2   lg_id          126314 non-null  object
#  3   _iscopy        126314 non-null  int64
#  4   year_id        126314 non-null  int64
#  5   date_game      126314 non-null  object
#  6   seasongame     126314 non-null  int64
#  7   is_playoffs    126314 non-null  int64
#  8   team_id        126314 non-null  object
#  9   fran_id        126314 non-null  object
#  10  pts            126314 non-null  int64
#  11  elo_i          126314 non-null  float64
#  12  elo_n          126314 non-null  float64
#  13  win_equiv      126314 non-null  float64
#  14  opp_id         126314 non-null  object
#  15  opp_fran       126314 non-null  object
#  16  opp_pts        126314 non-null  int64
#  17  opp_elo_i      126314 non-null  float64
#  18  opp_elo_n      126314 non-null  float64
#  19  game_location  126314 non-null  object
#  20  game_result    126314 non-null  object
#  21  forecast       126314 non-null  float64
#  22  notes          5424 non-null    object
# dtypes: float64(6), int64(7), object(10)
# memory usage: 22.2+ MB

# %%
df.describecribe()
# Out:
#        gameorder   _iscopy    year_id  seasongame  is_playoffs        pts  \
# count  126314.00  126314.0  126314.00   126314.00    126314.00  126314.00
# mean    31579.00       0.5    1988.20       43.53         0.06     102.73
# std     18231.93       0.5      17.58       25.38         0.24      14.81
# min         1.00       0.0    1947.00        1.00         0.00       0.00
# 25%     15790.00       0.0    1975.00       22.00         0.00      93.00
# 50%     31579.00       0.5    1990.00       43.00         0.00     103.00
# 75%     47368.00       1.0    2003.00       65.00         0.00     112.00
# max     63157.00       1.0    2015.00      108.00         1.00     186.00
#
#            elo_i      elo_n  win_equiv    opp_pts  opp_elo_i  opp_elo_n  \
# count  126314.00  126314.00  126314.00  126314.00  126314.00  126314.00
# mean     1495.24    1495.24      41.71     102.73    1495.24    1495.24
# std       112.14     112.46      10.63      14.81     112.14     112.46
# min      1091.64    1085.77      10.15       0.00    1091.64    1085.77
# 25%      1417.24    1416.99      34.10      93.00    1417.24    1416.99
# 50%      1500.95    1500.95      42.11     103.00    1500.95    1500.95
# 75%      1576.06    1576.29      49.64     112.00    1576.06    1576.29
# max      1853.10    1853.10      71.11     186.00    1853.10    1853.10
#
#         forecast
# count  126314.00
# mean        0.50
# std         0.22
# min         0.02
# 25%         0.33
# 50%         0.50
# 75%         0.67
# max         0.98

# %%
df['team_id'].value_counts()
# Out:
# BOS    5997
# NYK    5769
# LAL    5078
# DET    4985
# PHI    4533
#        ...
# INJ      60
# TRH      60
# PIT      60
# DTF      60
# SDS      11
# Name: team_id, Length: 104, dtype: int64

# %%
df['fran_id'].value_counts()
# Out:
# Lakers          6024
# Celtics         5997
# Knicks          5769
# Warriors        5657
# Pistons         5650
# Sixers          5644
# Hawks           5572
# Kings           5475
# Wizards         4582
# Spurs           4309
# Bulls           4307
# Pacers          4227
# Thunder         4178
# Rockets         4154
# Nuggets         4120
# Nets            4106
# Suns            4080
# Bucks           4034
# Trailblazers    3870
# Cavaliers       3810
# Clippers        3733
# Jazz            3555
# Mavericks       3013
# Heat            2371
# Pelicans        2254
# Magic           2207
# Timberwolves    2131
# Grizzlies       1657
# Raptors         1634
# Hornets          894
# Colonels         846
# Squires          799
# Spirits          777
# Stars            756
# Sounds           697
# Baltimore        467
# Floridians       440
# Condors          430
# Capitols         291
# Olympians        282
# Sails            274
# Stags            260
# Bombers          249
# Steamrollers     168
# Packers           72
# Redskins          65
# Rebels            63
# Waterloo          62
# Denver            62
# Huskies           60
# Jets              60
# Falcons           60
# Ironmen           60
# Name: fran_id, dtype: int64

# %%
df.loc[df['fran_id'] == 'Lakers', 'team_id'].value_counts()
# Out:
# LAL    5078
# MNL     946
# Name: team_id, dtype: int64

# %%
df.loc[df['team_id'] == 'MNL', 'date_game'].min()
# Out:
# '1/1/1949'

# %%
df.loc[df['team_id'] == 'LAL', 'date_game'].min()
# Out:
# '1/1/1961'

# %%
df.loc[df['team_id'] == 'LAL', 'date_game'].agg({'min','max'})
# Out:
# max    6/9/2009
# min    1/1/1961
# Name: date_game, dtype: object

# %%
df.loc[df['team_id'] == 'MNL']
# Out:
#       gameorder       game_id lg_id  _iscopy  year_id   date_game  seasongame  \
# 1136        569  194811040BLB   NBA        1     1949   11/4/1948           1
# 1152        577  194811060WSC   NBA        1     1949   11/6/1948           2
# 1159        580  194811090BOS   NBA        1     1949   11/9/1948           3
# 1170        586  194811110NYK   NBA        1     1949  11/11/1948           4
# 1183        592  194811130PRO   NBA        1     1949  11/13/1948           5
# ...         ...           ...   ...      ...      ...         ...         ...
# 9701       4851  196003190LAL   NBA        0     1960   3/19/1960          80
# 9702       4852  196003200LAL   NBA        0     1960   3/20/1960          81
# 9709       4855  196003220STL   NBA        1     1960   3/22/1960          82
# 9711       4856  196003240LAL   NBA        0     1960   3/24/1960          83
# 9715       4858  196003260STL   NBA        1     1960   3/26/1960          84
#
#       is_playoffs team_id fran_id  ...  win_equiv  opp_id      opp_fran  \
# 1136            0     MNL  Lakers  ...      51.22     BLB     Baltimore
# 1152            0     MNL  Lakers  ...      50.62     WSC      Capitols
# 1159            0     MNL  Lakers  ...      48.34     BOS       Celtics
# 1170            0     MNL  Lakers  ...      49.50     NYK        Knicks
# 1183            0     MNL  Lakers  ...      50.33     PRO  Steamrollers
# ...           ...     ...     ...  ...        ...     ...           ...
# 9701            1     MNL  Lakers  ...      36.05     STL         Hawks
# 9702            1     MNL  Lakers  ...      36.57     STL         Hawks
# 9709            1     MNL  Lakers  ...      38.14     STL         Hawks
# 9711            1     MNL  Lakers  ...      36.15     STL         Hawks
# 9715            1     MNL  Lakers  ...      35.69     STL         Hawks
#
#       opp_pts opp_elo_i opp_elo_n  game_location  game_result  forecast notes
# 1136       72   1507.21   1491.95              A            W      0.39   NaN
# 1152       67   1481.87   1487.92              A            L      0.44   NaN
# 1159       77   1359.33   1382.05              A            L      0.61   NaN
# 1170       68   1460.42   1448.95              A            W      0.43   NaN
# 1183       67   1245.95   1237.63              A            W      0.74   NaN
# ...       ...       ...       ...            ...          ...       ...   ...
# 9701       93   1564.97   1571.43              H            L      0.51   NaN
# 9702      101   1571.43   1566.48              H            W      0.49   NaN
# 9709      110   1566.48   1551.37              A            W      0.24   NaN
# 9711      117   1551.37   1570.45              H            L      0.55   NaN
# 9715       97   1570.45   1574.90              A            L      0.24   NaN
#
# [946 rows x 23 columns]

# %%
df.loc[df['team_id'] == 'BOS', 'pts'].sum()
# Out:
# 626484

# %%
df.loc[df['team_id'] == 'BOS', 'pts'].agg({'min', 'max', 'sum'})
# Out:
# sum    626484
# max       173
# min        43
# Name: pts, dtype: int64

# %%
df.loc[df['team_id'] == 'BOS', 'opp_pts'].sum()
# Out:
# 611049

# %%
colors = pd.Series(
    ['red','purple','blue','green','yellow'],
    index = [0,1,2,3,4]
)

# %%
colors[1]
# Out:
# 'purple'

# %%
colors.iloc[3]
# Out:
# 'green'

# %%
revenues = pd.Series([5555,7000,1980])

# %%
revenues
# Out:
# 0    5555
# 1    7000
# 2    1980
# dtype: int64

# %%
city_revenue = pd.Series(
    [4200,8000,6500],
    index=['Amsterdam','Toronto','Tokyo']
)
city_revenue
# Out:
# Amsterdam    4200
# Toronto      8000
# Tokyo        6500
# dtype: int64

# %%
city_revenue['Amsterdam']
# Out:
# 4200

# %%
city_employee_count = pd.Series({"Amsterdam":5,"Tokyo":8})

# %%
city_data = pd.DataFrame({
    "revenue":city_revenue,
    "employee_count":city_employee_count
})

# %%
city_data
# Out:
#            revenue  employee_count
# Amsterdam     4200             5.0
# Tokyo         6500             8.0
# Toronto       8000             NaN

# %%
city_data.revenue
# Out:
# Amsterdam    4200
# Tokyo        6500
# Toronto      8000
# Name: revenue, dtype: int64

# %%
colors = pd.Series(
    ['red','purple','blue','green','yellow'],
    index = [8,1,2,9,4]
)

# %%
colors[1]
# Out:
# 'purple'

# %%
colors[9]
# Out:
# 'green'

# %%
colors.iloc[0]
# Out:
# 'red'

# %%
df.iloc[-1]
# Out:
# gameorder               63157
# game_id          201506170CLE
# lg_id                     NBA
# _iscopy                     1
# year_id                  2015
# date_game           6/16/2015
# seasongame                103
# is_playoffs                 1
# team_id                   GSW
# fran_id              Warriors
# pts                       105
# elo_i                 1.8e+03
# elo_n                 1.8e+03
# win_equiv                  69
# opp_id                    CLE
# opp_fran            Cavaliers
# opp_pts                    97
# opp_elo_i             1.7e+03
# opp_elo_n             1.7e+03
# game_location               A
# game_result                 W
# forecast                 0.52
# notes                     NaN
# Name: 126313, dtype: object

# %%
df.loc[1:50,['fran_id','opp_id','pts','opp_pts']]
# Out:
#          fran_id opp_id  pts  opp_pts
# 1         Knicks    TRH   68       66
# 2          Stags    NYK   63       47
# 3         Knicks    CHS   47       63
# 4        Falcons    WSC   33       50
# 5       Capitols    DTF   50       33
# 6        Celtics    PRO   53       59
# 7   Steamrollers    BOS   59       53
# 8        Ironmen    STB   51       56
# 9        Bombers    PIT   56       51
# 10       Huskies    CLR   60       71
# 11        Rebels    TRH   71       60
# 12       Ironmen    WSC   56       71
# 13      Capitols    PIT   71       56
# 14       Celtics    CHS   55       57
# 15         Stags    BOS   57       55
# 16       Bombers    DTF   53       49
# 17       Falcons    STB   49       53
# 18       Ironmen    PHW   75       81
# 19      Warriors    PIT   81       75
# 20  Steamrollers    CHS   73       65
# 21         Stags    PRO   65       73
# 22       Bombers    NYK   63       68
# 23        Knicks    STB   68       63
# 24       Huskies    DTF   73       71
# 25       Falcons    TRH   71       73
# 26       Huskies    CHS   54       62
# 27         Stags    TRH   62       54
# 28       Celtics    DTF   46       69
# 29       Falcons    BOS   69       46
# 30  Steamrollers    PIT   76       66
# 31       Ironmen    PRO   66       76
# 32       Bombers    WSC   70       69
# 33      Capitols    STB   69       70
# 34        Rebels    WSC   92       68
# 35      Capitols    CLR   68       92
# 36         Stags    NYK   78       68
# 37        Knicks    CHS   68       78
# 38       Ironmen    PRO   84       71
# 39  Steamrollers    PIT   71       84
# 40       Celtics    CHS   61       71
# 41         Stags    BOS   71       61
# 42       Falcons    PRO   68       70
# 43  Steamrollers    DTF   70       68
# 44      Warriors    WSC   68       65
# 45      Capitols    PHW   65       68
# 46       Celtics    STB   62       64
# 47       Bombers    BOS   64       62
# 48  Steamrollers    TRH   68       85
# 49       Huskies    PRO   85       68
# 50       Huskies    BOS   49       53

# %%
city_data['revenue']
# Out:
# Amsterdam    4200
# Tokyo        6500
# Toronto      8000
# Name: revenue, dtype: int64

# %%
current_decade = df[df['year_id']>2010]
current_decade
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id   date_game  \
# 113656      56829  201010260BOS   NBA        1     2011  10/26/2010
# 113657      56829  201010260BOS   NBA        0     2011  10/26/2010
# 113658      56830  201010260LAL   NBA        1     2011  10/26/2010
# 113659      56830  201010260LAL   NBA        0     2011  10/26/2010
# 113660      56831  201010260POR   NBA        1     2011  10/26/2010
# ...           ...           ...   ...      ...      ...         ...
# 126309      63155  201506110CLE   NBA        0     2015   6/11/2015
# 126310      63156  201506140GSW   NBA        0     2015   6/14/2015
# 126311      63156  201506140GSW   NBA        1     2015   6/14/2015
# 126312      63157  201506170CLE   NBA        0     2015   6/16/2015
# 126313      63157  201506170CLE   NBA        1     2015   6/16/2015
#
#         seasongame  is_playoffs team_id    fran_id  ...  win_equiv  opp_id  \
# 113656           1            0     MIA       Heat  ...      45.14     BOS
# 113657           1            0     BOS    Celtics  ...      53.75     MIA
# 113658           1            0     HOU    Rockets  ...      40.90     LAL
# 113659           1            0     LAL     Lakers  ...      55.61     HOU
# 113660           1            0     PHO       Suns  ...      53.88     POR
# ...            ...          ...     ...        ...  ...        ...     ...
# 126309         100            1     CLE  Cavaliers  ...      60.31     GSW
# 126310         102            1     GSW   Warriors  ...      68.01     CLE
# 126311         101            1     CLE  Cavaliers  ...      60.01     GSW
# 126312         102            1     CLE  Cavaliers  ...      59.29     GSW
# 126313         103            1     GSW   Warriors  ...      68.52     CLE
#
#             opp_fran  opp_pts opp_elo_i opp_elo_n  game_location  game_result  \
# 113656       Celtics       88   1625.10   1629.30              A            L
# 113657          Heat       80   1547.36   1543.16              H            W
# 113658        Lakers      112   1647.60   1649.20              A            L
# 113659       Rockets      110   1504.20   1502.60              H            W
# 113660  Trailblazers      106   1552.81   1565.22              A            L
# ...              ...      ...       ...       ...            ...          ...
# 126309      Warriors      103   1790.96   1809.98              H            L
# 126310     Cavaliers       91   1704.39   1700.74              H            W
# 126311      Warriors      104   1809.98   1813.63              A            L
# 126312      Warriors      105   1813.63   1822.29              H            L
# 126313     Cavaliers       97   1700.74   1692.09              A            W
#
#         forecast notes
# 113656      0.26   NaN
# 113657      0.74   NaN
# 113658      0.20   NaN
# 113659      0.80   NaN
# 113660      0.49   NaN
# ...          ...   ...
# 126309      0.55   NaN
# 126310      0.77   NaN
# 126311      0.23   NaN
# 126312      0.48   NaN
# 126313      0.52   NaN
#
# [12658 rows x 23 columns]

# %%
current_decade.shape
# Out:
# (12658, 23)

# %%
current_decade = df[df.year_id>2010]
current_decade
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id   date_game  \
# 113656      56829  201010260BOS   NBA        1     2011  10/26/2010
# 113657      56829  201010260BOS   NBA        0     2011  10/26/2010
# 113658      56830  201010260LAL   NBA        1     2011  10/26/2010
# 113659      56830  201010260LAL   NBA        0     2011  10/26/2010
# 113660      56831  201010260POR   NBA        1     2011  10/26/2010
# ...           ...           ...   ...      ...      ...         ...
# 126309      63155  201506110CLE   NBA        0     2015   6/11/2015
# 126310      63156  201506140GSW   NBA        0     2015   6/14/2015
# 126311      63156  201506140GSW   NBA        1     2015   6/14/2015
# 126312      63157  201506170CLE   NBA        0     2015   6/16/2015
# 126313      63157  201506170CLE   NBA        1     2015   6/16/2015
#
#         seasongame  is_playoffs team_id    fran_id  ...  win_equiv  opp_id  \
# 113656           1            0     MIA       Heat  ...      45.14     BOS
# 113657           1            0     BOS    Celtics  ...      53.75     MIA
# 113658           1            0     HOU    Rockets  ...      40.90     LAL
# 113659           1            0     LAL     Lakers  ...      55.61     HOU
# 113660           1            0     PHO       Suns  ...      53.88     POR
# ...            ...          ...     ...        ...  ...        ...     ...
# 126309         100            1     CLE  Cavaliers  ...      60.31     GSW
# 126310         102            1     GSW   Warriors  ...      68.01     CLE
# 126311         101            1     CLE  Cavaliers  ...      60.01     GSW
# 126312         102            1     CLE  Cavaliers  ...      59.29     GSW
# 126313         103            1     GSW   Warriors  ...      68.52     CLE
#
#             opp_fran  opp_pts opp_elo_i opp_elo_n  game_location  game_result  \
# 113656       Celtics       88   1625.10   1629.30              A            L
# 113657          Heat       80   1547.36   1543.16              H            W
# 113658        Lakers      112   1647.60   1649.20              A            L
# 113659       Rockets      110   1504.20   1502.60              H            W
# 113660  Trailblazers      106   1552.81   1565.22              A            L
# ...              ...      ...       ...       ...            ...          ...
# 126309      Warriors      103   1790.96   1809.98              H            L
# 126310     Cavaliers       91   1704.39   1700.74              H            W
# 126311      Warriors      104   1809.98   1813.63              A            L
# 126312      Warriors      105   1813.63   1822.29              H            L
# 126313     Cavaliers       97   1700.74   1692.09              A            W
#
#         forecast notes
# 113656      0.26   NaN
# 113657      0.74   NaN
# 113658      0.20   NaN
# 113659      0.80   NaN
# 113660      0.49   NaN
# ...          ...   ...
# 126309      0.55   NaN
# 126310      0.77   NaN
# 126311      0.23   NaN
# 126312      0.48   NaN
# 126313      0.52   NaN
#
# [12658 rows x 23 columns]

# %%
current_decade = df[df.pts>100]
current_decade
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id  date_game  \
# 256           129  194701010CHS   NBA        1     1947   1/1/1947
# 313           157  194701140TRH   NBA        1     1947  1/14/1947
# 399           200  194702020CLR   NBA        1     1947   2/2/1947
# 416           209  194702060CHS   NBA        0     1947   2/6/1947
# 444           223  194702120PIT   NBA        1     1947  2/12/1947
# ...           ...           ...   ...      ...      ...        ...
# 126301      63151  201505270GSW   NBA        0     2015  5/27/2015
# 126303      63152  201506040GSW   NBA        0     2015   6/4/2015
# 126308      63155  201506110CLE   NBA        1     2015  6/11/2015
# 126310      63156  201506140GSW   NBA        0     2015  6/14/2015
# 126313      63157  201506170CLE   NBA        1     2015  6/16/2015
#
#         seasongame  is_playoffs team_id   fran_id  ...  win_equiv  opp_id  \
# 256             26            0     STB   Bombers  ...      47.14     CHS
# 313             28            0     PHW  Warriors  ...      45.04     TRH
# 399             37            0     WSC  Capitols  ...      57.21     CLR
# 416             38            0     CHS     Stags  ...      48.49     PIT
# 444             40            0     CHS     Stags  ...      51.20     PIT
# ...            ...          ...     ...       ...  ...        ...     ...
# 126301          97            1     GSW  Warriors  ...      67.32     HOU
# 126303          98            1     GSW  Warriors  ...      67.57     CLE
# 126308         101            1     GSW  Warriors  ...      67.79     CLE
# 126310         102            1     GSW  Warriors  ...      68.01     CLE
# 126313         103            1     GSW  Warriors  ...      68.52     CLE
#
#          opp_fran  opp_pts opp_elo_i opp_elo_n  game_location  game_result  \
# 256         Stags       90   1353.05   1335.41              A            W
# 313       Huskies       74   1263.26   1237.16              A            W
# 399        Rebels       81   1311.76   1294.46              A            W
# 416       Ironmen       85   1206.19   1200.56              H            W
# 444       Ironmen       82   1208.96   1197.40              A            W
# ...           ...      ...       ...       ...            ...          ...
# 126301    Rockets       90   1658.99   1654.64              H            W
# 126303  Cavaliers      100   1712.12   1708.17              H            W
# 126308  Cavaliers       82   1723.41   1704.39              A            W
# 126310  Cavaliers       91   1704.39   1700.74              H            W
# 126313  Cavaliers       97   1700.74   1692.09              A            W
#
#         forecast notes
# 256         0.34   NaN
# 313         0.43   NaN
# 399         0.55   NaN
# 416         0.82   NaN
# 444         0.61   NaN
# ...          ...   ...
# 126301      0.80   NaN
# 126303      0.75   NaN
# 126308      0.45   NaN
# 126310      0.77   NaN
# 126313      0.52   NaN
#
# [70729 rows x 23 columns]

# %%
current_decade.shape
# Out:
# (70729, 23)

# %%
games_with_notes = df[df["notes"].notnull()]

# %%
games_with_notes
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id   date_game  \
# 930           466  194801300BLB   NBA        1     1948   1/30/1948
# 931           466  194801300BLB   NBA        0     1948   1/30/1948
# 1084          543  194803230CHS   NBA        1     1948   3/23/1948
# 1085          543  194803230CHS   NBA        0     1948   3/23/1948
# 1088          545  194803250CHS   NBA        1     1948   3/25/1948
# ...           ...           ...   ...      ...      ...         ...
# 122207      61104  201401160ATL   NBA        0     2014   1/16/2014
# 123916      61959  201411120MIN   NBA        1     2015  11/12/2014
# 123917      61959  201411120MIN   NBA        0     2015  11/12/2014
# 124862      62432  201501150MIL   NBA        0     2015   1/15/2015
# 124863      62432  201501150MIL   NBA        1     2015   1/15/2015
#
#         seasongame  is_playoffs team_id       fran_id  ...  win_equiv  opp_id  \
# 930             28            0     WSC      Capitols  ...      47.07     BLB
# 931             31            0     BLB     Baltimore  ...      46.41     WSC
# 1084            49            1     WSC      Capitols  ...      47.71     CHS
# 1085            49            1     CHS         Stags  ...      46.09     WSC
# 1088            49            1     BLB     Baltimore  ...      50.04     CHS
# ...            ...          ...     ...           ...  ...        ...     ...
# 122207          39            0     ATL         Hawks  ...      39.24     BRK
# 123916           8            0     HOU       Rockets  ...      54.89     MIN
# 123917           7            0     MIN  Timberwolves  ...      40.13     HOU
# 124862          40            0     MIL         Bucks  ...      41.14     NYK
# 124863          41            0     NYK        Knicks  ...      21.19     MIL
#
#             opp_fran  opp_pts opp_elo_i opp_elo_n  game_location  game_result  \
# 930        Baltimore       95   1434.05   1448.50              A            L
# 931         Capitols       71   1469.35   1454.90              H            W
# 1084           Stags       74   1440.72   1445.42              A            L
# 1085        Capitols       70   1465.90   1461.20              H            W
# 1088           Stags       72   1445.42   1438.36              A            W
# ...              ...      ...       ...       ...            ...          ...
# 122207          Nets      127   1454.65   1472.11              N            L
# 123916  Timberwolves      101   1502.92   1496.24              N            W
# 123917       Rockets      113   1635.77   1642.45              N            L
# 124862        Knicks       79   1304.46   1298.50              N            W
# 124863         Bucks       95   1499.90   1505.86              N            L
#
#         forecast                                      notes
# 930         0.41       at Baltimore's Fifth Regiment Armory
# 931         0.59       at Baltimore's Fifth Regiment Armory
# 1084        0.39                                 Tiebreaker
# 1085        0.61                                 Tiebreaker
# 1088        0.40                                 Tiebreaker
# ...          ...                                        ...
# 122207      0.57                         at London, England
# 123916      0.68  at Mexico City Arena, Mexico City, Mexico
# 123917      0.32  at Mexico City Arena, Mexico City, Mexico
# 124862      0.75                 at The O2, London, England
# 124863      0.25                 at The O2, London, England
#
# [5424 rows x 23 columns]

# %%
ers = df[df['fran_id'].str.endswith('ers')]

# %%
ers
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id  date_game  \
# 7               4  194611020PRO   NBA        0     1947  11/2/1946
# 9               5  194611020STB   NBA        0     1947  11/2/1946
# 16              9  194611050DTF   NBA        1     1947  11/5/1946
# 20             11  194611070PRO   NBA        0     1947  11/7/1946
# 22             12  194611070STB   NBA        0     1947  11/7/1946
# ...           ...           ...   ...      ...      ...        ...
# 126304      63153  201506070GSW   NBA        1     2015   6/7/2015
# 126307      63154  201506090CLE   NBA        0     2015   6/9/2015
# 126309      63155  201506110CLE   NBA        0     2015  6/11/2015
# 126311      63156  201506140GSW   NBA        1     2015  6/14/2015
# 126312      63157  201506170CLE   NBA        0     2015  6/16/2015
#
#         seasongame  is_playoffs team_id       fran_id  ...  win_equiv  opp_id  \
# 7                1            0     PRO  Steamrollers  ...      41.54     BOS
# 9                1            0     STB       Bombers  ...      41.49     PIT
# 16               2            0     STB       Bombers  ...      42.35     DTF
# 20               2            0     PRO  Steamrollers  ...      42.21     CHS
# 22               3            0     STB       Bombers  ...      41.27     NYK
# ...            ...          ...     ...           ...  ...        ...     ...
# 126304          98            1     CLE     Cavaliers  ...      61.31     GSW
# 126307          99            1     CLE     Cavaliers  ...      61.83     GSW
# 126309         100            1     CLE     Cavaliers  ...      60.31     GSW
# 126311         101            1     CLE     Cavaliers  ...      60.01     GSW
# 126312         102            1     CLE     Cavaliers  ...      59.29     GSW
#
#         opp_fran  opp_pts opp_elo_i opp_elo_n  game_location  game_result  \
# 7        Celtics       53   1300.00   1294.85              H            W
# 9        Ironmen       51   1300.00   1295.31              H            W
# 16       Falcons       49   1279.62   1271.46              A            W
# 20         Stags       65   1316.08   1309.73              H            W
# 22        Knicks       68   1297.07   1307.32              H            L
# ...          ...      ...       ...       ...            ...          ...
# 126304  Warriors       93   1806.20   1797.50              A            W
# 126307  Warriors       91   1797.50   1790.96              H            W
# 126309  Warriors      103   1790.96   1809.98              H            L
# 126311  Warriors      104   1809.98   1813.63              A            L
# 126312  Warriors      105   1813.63   1822.29              H            L
#
#         forecast notes
# 7           0.64   NaN
# 9           0.64   NaN
# 16          0.39   NaN
# 20          0.63   NaN
# 22          0.66   NaN
# ...          ...   ...
# 126304      0.24   NaN
# 126307      0.53   NaN
# 126309      0.55   NaN
# 126311      0.23   NaN
# 126312      0.48   NaN
#
# [27797 rows x 23 columns]

# %%
df[
    (df["_iscopy"] == 0) &
    (df["pts"] > 100) &
    (df["opp_pts" > 100]) &
    (df[""])
]
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id  date_game  \
# 416           209  194702060CHS   NBA        0     1947   2/6/1947
# 561           281  194703080CHS   NBA        0     1947   3/8/1947
# 643           322  194703260WSC   NBA        0     1947  3/26/1947
# 872           437  194801100WSC   NBA        0     1948  1/10/1948
# 946           474  194802040NYK   NBA        0     1948   2/4/1948
# ...           ...           ...   ...      ...      ...        ...
# 126269      63135  201505120HOU   NBA        0     2015  5/12/2015
# 126276      63139  201505140LAC   NBA        0     2015  5/14/2015
# 126294      63148  201505240CLE   NBA        0     2015  5/24/2015
# 126297      63149  201505250HOU   NBA        0     2015  5/25/2015
# 126310      63156  201506140GSW   NBA        0     2015  6/14/2015
#
#         seasongame  is_playoffs team_id    fran_id  ...  win_equiv  opp_id  \
# 416             38            0     CHS      Stags  ...      48.49     PIT
# 561             50            0     CHS      Stags  ...      52.70     PRO
# 643             59            0     WSC   Capitols  ...      61.63     CHS
# 872             22            0     WSC   Capitols  ...      49.10     PHW
# 946             33            0     NYK     Knicks  ...      44.80     PRO
# ...            ...          ...     ...        ...  ...        ...     ...
# 126269          92            1     HOU    Rockets  ...      54.60     LAC
# 126276          95            1     LAC   Clippers  ...      60.31     HOU
# 126294          95            1     CLE  Cavaliers  ...      60.25     ATL
# 126297          98            1     HOU    Rockets  ...      56.41     GSW
# 126310         102            1     GSW   Warriors  ...      68.01     CLE
#
#             opp_fran  opp_pts opp_elo_i opp_elo_n  game_location  game_result  \
# 416          Ironmen       85   1206.19   1200.56              H            W
# 561     Steamrollers       81   1268.22   1261.57              H            W
# 643            Stags       77   1402.23   1393.86              H            W
# 872         Warriors       99   1384.20   1380.48              H            W
# 946     Steamrollers       69   1229.48   1222.91              H            W
# ...              ...      ...       ...       ...            ...          ...
# 126269      Clippers      103   1743.11   1724.76              H            W
# 126276       Rockets      119   1639.32   1659.66              H            L
# 126294         Hawks      111   1591.40   1589.20              H            W
# 126297      Warriors      115   1813.45   1797.89              H            W
# 126310     Cavaliers       91   1704.39   1700.74              H            W
#
#         forecast notes
# 416         0.82   NaN
# 561         0.80   NaN
# 643         0.77   NaN
# 872         0.75   NaN
# 946         0.85   NaN
# ...          ...   ...
# 126269      0.47   NaN
# 126276      0.74   NaN
# 126294      0.77   NaN
# 126297      0.40   NaN
# 126310      0.77   NaN
#
# [19298 rows x 23 columns]

# %%
city_revenue.sum()
# Out:
# 18700

# %%
df.groupby("fran_id", sort=True)['pts'].sum()
# Out:
# fran_id
# Baltimore        37219
# Bombers          17793
# Bucks           418326
# Bulls           437269
# Capitols         22387
# Cavaliers       380416
# Celtics         626484
# Clippers        380523
# Colonels         94435
# Condors          49642
# Denver            4818
# Falcons           3797
# Floridians       49568
# Grizzlies       157683
# Hawks           567261
# Heat            229103
# Hornets          84489
# Huskies           3995
# Ironmen           3674
# Jazz            363155
# Jets              4482
# Kings           569245
# Knicks          582497
# Lakers          637444
# Magic           219436
# Mavericks       309239
# Nets            417809
# Nuggets         445780
# Olympians        22864
# Pacers          438288
# Packers           6193
# Pelicans        220794
# Pistons         572758
# Raptors         158370
# Rebels            4474
# Redskins          5372
# Rockets         432504
# Sails            30080
# Sixers          585891
# Sounds           75582
# Spirits          85874
# Spurs           453822
# Squires          91127
# Stags            20398
# Stars            84940
# Steamrollers     12372
# Suns            437486
# Thunder         437735
# Timberwolves    207693
# Trailblazers    402695
# Warriors        591224
# Waterloo          4921
# Wizards         474809
# Name: pts, dtype: int64

# %%
df[
    (df['fran_id'] == 'Spurs') &
    (df['year_id'] > 2010)
].groupby(['year_id','game_result'])['game_id'].count()
# Out:
# year_id  game_result
# 2011     L              25
#          W              63
# 2012     L              20
#          W              60
# 2013     L              30
#          W              73
# 2014     L              27
#          W              78
# 2015     L              31
#          W              58
# Name: game_id, dtype: int64

# %%
nba = df.copy()

# %%
nba['difference'] = df.pts - df.opp_pts

# %%
nba
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id  date_game  \
# 0               1  194611010TRH   NBA        0     1947  11/1/1946
# 1               1  194611010TRH   NBA        1     1947  11/1/1946
# 2               2  194611020CHS   NBA        0     1947  11/2/1946
# 3               2  194611020CHS   NBA        1     1947  11/2/1946
# 4               3  194611020DTF   NBA        0     1947  11/2/1946
# ...           ...           ...   ...      ...      ...        ...
# 126309      63155  201506110CLE   NBA        0     2015  6/11/2015
# 126310      63156  201506140GSW   NBA        0     2015  6/14/2015
# 126311      63156  201506140GSW   NBA        1     2015  6/14/2015
# 126312      63157  201506170CLE   NBA        0     2015  6/16/2015
# 126313      63157  201506170CLE   NBA        1     2015  6/16/2015
#
#         seasongame  is_playoffs team_id    fran_id  ...  opp_id   opp_fran  \
# 0                1            0     TRH    Huskies  ...     NYK     Knicks
# 1                1            0     NYK     Knicks  ...     TRH    Huskies
# 2                1            0     CHS      Stags  ...     NYK     Knicks
# 3                2            0     NYK     Knicks  ...     CHS      Stags
# 4                1            0     DTF    Falcons  ...     WSC   Capitols
# ...            ...          ...     ...        ...  ...     ...        ...
# 126309         100            1     CLE  Cavaliers  ...     GSW   Warriors
# 126310         102            1     GSW   Warriors  ...     CLE  Cavaliers
# 126311         101            1     CLE  Cavaliers  ...     GSW   Warriors
# 126312         102            1     CLE  Cavaliers  ...     GSW   Warriors
# 126313         103            1     GSW   Warriors  ...     CLE  Cavaliers
#
#         opp_pts  opp_elo_i opp_elo_n game_location  game_result  forecast  \
# 0            68    1300.00   1306.72             H            L      0.64
# 1            66    1300.00   1293.28             A            W      0.36
# 2            47    1306.72   1297.07             H            W      0.63
# 3            63    1300.00   1309.65             A            L      0.37
# 4            50    1300.00   1320.38             H            L      0.64
# ...         ...        ...       ...           ...          ...       ...
# 126309      103    1790.96   1809.98             H            L      0.55
# 126310       91    1704.39   1700.74             H            W      0.77
# 126311      104    1809.98   1813.63             A            L      0.23
# 126312      105    1813.63   1822.29             H            L      0.48
# 126313       97    1700.74   1692.09             A            W      0.52
#
#         notes difference
# 0         NaN         -2
# 1         NaN          2
# 2         NaN         16
# 3         NaN        -16
# 4         NaN        -17
# ...       ...        ...
# 126309    NaN        -21
# 126310    NaN         13
# 126311    NaN        -13
# 126312    NaN         -8
# 126313    NaN          8
#
# [126314 rows x 24 columns]

# %%
nba['difference'].max()
# Out:
# 68

# %%
nba['difference'].min()
# Out:
# -68

# %%
renamed_nba = nba.rename(
    columns = {'game_result':'result'}
)

# %%
renamed_nba
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id  date_game  \
# 0               1  194611010TRH   NBA        0     1947  11/1/1946
# 1               1  194611010TRH   NBA        1     1947  11/1/1946
# 2               2  194611020CHS   NBA        0     1947  11/2/1946
# 3               2  194611020CHS   NBA        1     1947  11/2/1946
# 4               3  194611020DTF   NBA        0     1947  11/2/1946
# ...           ...           ...   ...      ...      ...        ...
# 126309      63155  201506110CLE   NBA        0     2015  6/11/2015
# 126310      63156  201506140GSW   NBA        0     2015  6/14/2015
# 126311      63156  201506140GSW   NBA        1     2015  6/14/2015
# 126312      63157  201506170CLE   NBA        0     2015  6/16/2015
# 126313      63157  201506170CLE   NBA        1     2015  6/16/2015
#
#         seasongame  is_playoffs team_id    fran_id  ...  opp_id   opp_fran  \
# 0                1            0     TRH    Huskies  ...     NYK     Knicks
# 1                1            0     NYK     Knicks  ...     TRH    Huskies
# 2                1            0     CHS      Stags  ...     NYK     Knicks
# 3                2            0     NYK     Knicks  ...     CHS      Stags
# 4                1            0     DTF    Falcons  ...     WSC   Capitols
# ...            ...          ...     ...        ...  ...     ...        ...
# 126309         100            1     CLE  Cavaliers  ...     GSW   Warriors
# 126310         102            1     GSW   Warriors  ...     CLE  Cavaliers
# 126311         101            1     CLE  Cavaliers  ...     GSW   Warriors
# 126312         102            1     CLE  Cavaliers  ...     GSW   Warriors
# 126313         103            1     GSW   Warriors  ...     CLE  Cavaliers
#
#         opp_pts  opp_elo_i opp_elo_n game_location  result  forecast  notes  \
# 0            68    1300.00   1306.72             H       L      0.64    NaN
# 1            66    1300.00   1293.28             A       W      0.36    NaN
# 2            47    1306.72   1297.07             H       W      0.63    NaN
# 3            63    1300.00   1309.65             A       L      0.37    NaN
# 4            50    1300.00   1320.38             H       L      0.64    NaN
# ...         ...        ...       ...           ...     ...       ...    ...
# 126309      103    1790.96   1809.98             H       L      0.55    NaN
# 126310       91    1704.39   1700.74             H       W      0.77    NaN
# 126311      104    1809.98   1813.63             A       L      0.23    NaN
# 126312      105    1813.63   1822.29             H       L      0.48    NaN
# 126313       97    1700.74   1692.09             A       W      0.52    NaN
#
#        difference
# 0              -2
# 1               2
# 2              16
# 3             -16
# 4             -17
# ...           ...
# 126309        -21
# 126310         13
# 126311        -13
# 126312         -8
# 126313          8
#
# [126314 rows x 24 columns]

# %%
elo_columns = ["elo_i",'elo_n','opp_elo_i','opp_elo_n']
nba.drop(elo_columns, inplace = True, axis=1)

# %%
nba.shape
# Out:
# (126314, 20)

# %%
nba
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id  date_game  \
# 0               1  194611010TRH   NBA        0     1947  11/1/1946
# 1               1  194611010TRH   NBA        1     1947  11/1/1946
# 2               2  194611020CHS   NBA        0     1947  11/2/1946
# 3               2  194611020CHS   NBA        1     1947  11/2/1946
# 4               3  194611020DTF   NBA        0     1947  11/2/1946
# ...           ...           ...   ...      ...      ...        ...
# 126309      63155  201506110CLE   NBA        0     2015  6/11/2015
# 126310      63156  201506140GSW   NBA        0     2015  6/14/2015
# 126311      63156  201506140GSW   NBA        1     2015  6/14/2015
# 126312      63157  201506170CLE   NBA        0     2015  6/16/2015
# 126313      63157  201506170CLE   NBA        1     2015  6/16/2015
#
#         seasongame  is_playoffs team_id    fran_id  pts  win_equiv opp_id  \
# 0                1            0     TRH    Huskies   66      40.29    NYK
# 1                1            0     NYK     Knicks   68      41.71    TRH
# 2                1            0     CHS      Stags   63      42.01    NYK
# 3                2            0     NYK     Knicks   47      40.69    CHS
# 4                1            0     DTF    Falcons   33      38.86    WSC
# ...            ...          ...     ...        ...  ...        ...    ...
# 126309         100            1     CLE  Cavaliers   82      60.31    GSW
# 126310         102            1     GSW   Warriors  104      68.01    CLE
# 126311         101            1     CLE  Cavaliers   91      60.01    GSW
# 126312         102            1     CLE  Cavaliers   97      59.29    GSW
# 126313         103            1     GSW   Warriors  105      68.52    CLE
#
#          opp_fran  opp_pts game_location game_result  forecast notes  \
# 0          Knicks       68             H           L      0.64   NaN
# 1         Huskies       66             A           W      0.36   NaN
# 2          Knicks       47             H           W      0.63   NaN
# 3           Stags       63             A           L      0.37   NaN
# 4        Capitols       50             H           L      0.64   NaN
# ...           ...      ...           ...         ...       ...   ...
# 126309   Warriors      103             H           L      0.55   NaN
# 126310  Cavaliers       91             H           W      0.77   NaN
# 126311   Warriors      104             A           L      0.23   NaN
# 126312   Warriors      105             H           L      0.48   NaN
# 126313  Cavaliers       97             A           W      0.52   NaN
#
#         difference
# 0               -2
# 1                2
# 2               16
# 3              -16
# 4              -17
# ...            ...
# 126309         -21
# 126310          13
# 126311         -13
# 126312          -8
# 126313           8
#
# [126314 rows x 20 columns]

# %%
nba.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 126314 entries, 0 to 126313
# Data columns (total 20 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   gameorder      126314 non-null  int64
#  1   game_id        126314 non-null  object
#  2   lg_id          126314 non-null  object
#  3   _iscopy        126314 non-null  int64
#  4   year_id        126314 non-null  int64
#  5   date_game      126314 non-null  datetime64[ns]
#  6   seasongame     126314 non-null  int64
#  7   is_playoffs    126314 non-null  int64
#  8   team_id        126314 non-null  object
#  9   fran_id        126314 non-null  object
#  10  pts            126314 non-null  int64
#  11  win_equiv      126314 non-null  float64
#  12  opp_id         126314 non-null  object
#  13  opp_fran       126314 non-null  object
#  14  opp_pts        126314 non-null  int64
#  15  game_location  126314 non-null  object
#  16  game_result    126314 non-null  object
#  17  forecast       126314 non-null  float64
#  18  notes          5424 non-null    object
#  19  difference     126314 non-null  int64
# dtypes: datetime64[ns](1), float64(2), int64(8), object(9)
# memory usage: 19.3+ MB

# %%
nba['date_game'] = pd.to_datetime(nba['date_game'])

# %%
nba.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 126314 entries, 0 to 126313
# Data columns (total 20 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   gameorder      126314 non-null  int64
#  1   game_id        126314 non-null  object
#  2   lg_id          126314 non-null  object
#  3   _iscopy        126314 non-null  int64
#  4   year_id        126314 non-null  int64
#  5   date_game      126314 non-null  datetime64[ns]
#  6   seasongame     126314 non-null  int64
#  7   is_playoffs    126314 non-null  int64
#  8   team_id        126314 non-null  object
#  9   fran_id        126314 non-null  object
#  10  pts            126314 non-null  int64
#  11  win_equiv      126314 non-null  float64
#  12  opp_id         126314 non-null  object
#  13  opp_fran       126314 non-null  object
#  14  opp_pts        126314 non-null  int64
#  15  game_location  126314 non-null  object
#  16  game_result    126314 non-null  object
#  17  forecast       126314 non-null  float64
#  18  notes          5424 non-null    object
#  19  difference     126314 non-null  int64
# dtypes: datetime64[ns](1), float64(2), int64(8), object(9)
# memory usage: 19.3+ MB

# %%
nba['game_location'].value_counts()
# Out:
# A    63138
# H    63138
# N       38
# Name: game_location, dtype: int64

# %%
nba['game_location'] = pd.Categorical(nba['game_location'])

# %%
nba['game_location'].dtype
# Out:
# CategoricalDtype(categories=['A', 'H', 'N'], ordered=False)

# %%
rows_without_missing_data = nba.dropna()

# %%
rows_without_missing_data.shape
# Out:
# (5424, 20)

# %%
data_with_default_notes = nba.copy()

# %%
data_with_default_notes['notes'].fillna(
    value='no notes at all',
    inplace=True
)

# %%
data_with_default_notes
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id  date_game  \
# 0               1  194611010TRH   NBA        0     1947 1946-11-01
# 1               1  194611010TRH   NBA        1     1947 1946-11-01
# 2               2  194611020CHS   NBA        0     1947 1946-11-02
# 3               2  194611020CHS   NBA        1     1947 1946-11-02
# 4               3  194611020DTF   NBA        0     1947 1946-11-02
# ...           ...           ...   ...      ...      ...        ...
# 126309      63155  201506110CLE   NBA        0     2015 2015-06-11
# 126310      63156  201506140GSW   NBA        0     2015 2015-06-14
# 126311      63156  201506140GSW   NBA        1     2015 2015-06-14
# 126312      63157  201506170CLE   NBA        0     2015 2015-06-16
# 126313      63157  201506170CLE   NBA        1     2015 2015-06-16
#
#         seasongame  is_playoffs team_id    fran_id  pts  win_equiv opp_id  \
# 0                1            0     TRH    Huskies   66      40.29    NYK
# 1                1            0     NYK     Knicks   68      41.71    TRH
# 2                1            0     CHS      Stags   63      42.01    NYK
# 3                2            0     NYK     Knicks   47      40.69    CHS
# 4                1            0     DTF    Falcons   33      38.86    WSC
# ...            ...          ...     ...        ...  ...        ...    ...
# 126309         100            1     CLE  Cavaliers   82      60.31    GSW
# 126310         102            1     GSW   Warriors  104      68.01    CLE
# 126311         101            1     CLE  Cavaliers   91      60.01    GSW
# 126312         102            1     CLE  Cavaliers   97      59.29    GSW
# 126313         103            1     GSW   Warriors  105      68.52    CLE
#
#          opp_fran  opp_pts game_location game_result  forecast  \
# 0          Knicks       68             H           L      0.64
# 1         Huskies       66             A           W      0.36
# 2          Knicks       47             H           W      0.63
# 3           Stags       63             A           L      0.37
# 4        Capitols       50             H           L      0.64
# ...           ...      ...           ...         ...       ...
# 126309   Warriors      103             H           L      0.55
# 126310  Cavaliers       91             H           W      0.77
# 126311   Warriors      104             A           L      0.23
# 126312   Warriors      105             H           L      0.48
# 126313  Cavaliers       97             A           W      0.52
#
#                   notes  difference
# 0       no notes at all          -2
# 1       no notes at all           2
# 2       no notes at all          16
# 3       no notes at all         -16
# 4       no notes at all         -17
# ...                 ...         ...
# 126309  no notes at all         -21
# 126310  no notes at all          13
# 126311  no notes at all         -13
# 126312  no notes at all          -8
# 126313  no notes at all           8
#
# [126314 rows x 20 columns]

# %%
nba.describe()
# Out:
#        gameorder   _iscopy    year_id  seasongame  is_playoffs        pts  \
# count  126314.00  126314.0  126314.00   126314.00    126314.00  126314.00
# mean    31579.00       0.5    1988.20       43.53         0.06     102.73
# std     18231.93       0.5      17.58       25.38         0.24      14.81
# min         1.00       0.0    1947.00        1.00         0.00       0.00
# 25%     15790.00       0.0    1975.00       22.00         0.00      93.00
# 50%     31579.00       0.5    1990.00       43.00         0.00     103.00
# 75%     47368.00       1.0    2003.00       65.00         0.00     112.00
# max     63157.00       1.0    2015.00      108.00         1.00     186.00
#
#        win_equiv    opp_pts   forecast  difference
# count  126314.00  126314.00  126314.00   126314.00
# mean       41.71     102.73       0.50        0.00
# std        10.63      14.81       0.22       13.37
# min        10.15       0.00       0.02      -68.00
# 25%        34.10      93.00       0.33       -9.00
# 50%        42.11     103.00       0.50        0.00
# 75%        49.64     112.00       0.67        9.00
# max        71.11     186.00       0.98       68.00

# %%
nba[nba['pts'] == 0]
# Out:
#        gameorder       game_id lg_id  _iscopy  year_id  date_game  seasongame  \
# 26684      13343  197210260VIR   ABA        1     1973 1972-10-26           7
#
#        is_playoffs team_id  fran_id  pts  win_equiv opp_id opp_fran  opp_pts  \
# 26684            0     DNR  Nuggets    0      40.41    VIR  Squires        2
#
#       game_location game_result  forecast                           notes  \
# 26684             A           L      0.33  at Richmond VA; forfeit to VIR
#
#        difference
# 26684          -2

# %%
nba[(nba['pts'] > nba['opp_pts']) & (nba['game_result'] != 'W')].empty
# Out:
# True

# %%
further_city_data = pd.DataFrame(
    {"revenue": [7000, 3400], "employee_count": [2, 2]},
    index=["New York", "Barcelona"]
)

# %%
further_city_data
# Out:
#            revenue  employee_count
# New York      7000               2
# Barcelona     3400               2

# %%
all_city_data = pd.concat([city_data, further_city_data], sort=False)

# %%
all_city_data
# Out:
#            revenue  employee_count
# Amsterdam     4200             5.0
# Tokyo         6500             8.0
# Toronto       8000             NaN
# New York      7000             2.0
# Barcelona     3400             2.0

# %%
city_countries = pd.DataFrame({
    "country": ["Holland", "Japan", "Holland", "Canada", "Spain"],
    "capital": [1, 1, 0, 0, 0]},
    index=["Amsterdam", "Tokyo", "Rotterdam", "Toronto", "Barcelona"]
)

# %%
city_countries
# Out:
#            country  capital
# Amsterdam  Holland        1
# Tokyo        Japan        1
# Rotterdam  Holland        0
# Toronto     Canada        0
# Barcelona    Spain        0

# %%
cities = pd.concat([all_city_data, city_countries], axis=1, sort=False)

# %%
cities
# Out:
#            revenue  employee_count  country  capital
# Amsterdam   4200.0             5.0  Holland      1.0
# Tokyo       6500.0             8.0    Japan      1.0
# Toronto     8000.0             NaN   Canada      0.0
# New York    7000.0             2.0      NaN      NaN
# Barcelona   3400.0             2.0    Spain      0.0
# Rotterdam      NaN             NaN  Holland      0.0

# %%
pd.concat([all_city_data, city_countries], axis=1, join="inner")
# Out:
#            revenue  employee_count  country  capital
# Amsterdam     4200             5.0  Holland        1
# Tokyo         6500             8.0    Japan        1
# Toronto       8000             NaN   Canada        0
# Barcelona     3400             2.0    Spain        0

# %%
# %matplotlib inline

# %%
nba[nba["fran_id"] == "Knicks"].groupby("year_id")["pts"].sum().plot()
# Out:
# <AxesSubplot:xlabel='year_id'>

# %%
nba["fran_id"].value_counts().head(10).plot(kind="bar")
# Out:
# <AxesSubplot:>
